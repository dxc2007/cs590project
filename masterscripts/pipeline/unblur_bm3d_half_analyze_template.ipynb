# %%
def get_metrics(input_file):
    print("input file: ", input_file)
    f = open(input_file,"r")
    fl = f.readlines()
    f.close()

    count = 1
    metrics=[]
    split_title = input_file.split("_")
#     print(split_title)
    metrics.extend([float(split_title[3]), split_title[4].split(".")[0]])
    for line in fl:
    #     print(line)
        if count >= 32 and count < 37:
            _, val_str = line.split(":") 
            if defocus.match(line):
                val=float(val_str.split(",")[0])
                metrics.append(val)
    #             print(val)
            if score.match(line):
                val=float(val_str)
                metrics.append(val)
    #             print(val)
            if thon_rings.match(line):
                val=float(val_str.split("Angstroms")[0])
                metrics.append(val)
    #             print(val)
        count+=1
    all_metrics[split_title[0]].append(metrics)

# %%
import sys
import re
import os
from collections import defaultdict
import glob
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline


defocus = re.compile(r"Estimated defocus values[ ]+: [-+]?[0-9]*\.?[0-9]+ , [-+]?[0-9]*\.?[0-9]+ Angstroms")
score = re.compile(r"Score[ ]+: [-+]?[0-9]*\.?[0-9]+")
thon_rings = re.compile(r"Thon rings with good fit up to[ ]+: [-+]?[0-9]*\.?[0-9]+ Angstroms")

all_metrics = defaultdict(list)
for f in glob.glob('*summary*.txt'):
    get_metrics(f)
# Out:
# input file:  stack1_ub_summary_50_cubic.txt
# input file:  stack10_ub_summary_250_linear.txt
# input file:  stack18_ub_summary_50_cubic.txt
# input file:  stack15_ub_summary_2000_cubic.txt
# input file:  stack10_ub_summary_1500_cubic.txt
# input file:  stack15_ub_summary_750_linear.txt
# input file:  stack18_ub_summary_1500_cubic.txt
# input file:  stack18_ub_summary_750_linear.txt
# input file:  stack10_ub_summary_1500_linear.txt
# input file:  stack19_ub_summary_750_cubic.txt
# input file:  stack19_ub_summary_2000_linear.txt
# input file:  stack19_ub_summary_1500_cubic.txt
# input file:  stack1_ub_summary_2000_cubic.txt
# input file:  stack18_ub_summary_2000_linear.txt
# input file:  stack15_ub_summary_50_cubic.txt
# input file:  stack19_ub_summary_1500_linear.txt
# input file:  stack1_ub_summary_50_linear.txt
# input file:  stack19_ub_summary_750_linear.txt
# input file:  stack10_ub_summary_750_cubic.txt
# input file:  stack19_ub_summary_50_cubic.txt
# input file:  stack19_ub_summary_250_linear.txt
# input file:  stack18_ub_summary_1500_linear.txt
# input file:  stack18_ub_summary_50_linear.txt
# input file:  stack1_ub_summary_250_cubic.txt
# input file:  stack15_ub_summary_1500_cubic.txt
# input file:  stack15_ub_summary_1500_linear.txt
# input file:  stack1_ub_summary_750_linear.txt
# input file:  stack1_ub_summary_2000_linear.txt
# input file:  stack10_ub_summary_2000_linear.txt
# input file:  stack15_ub_summary_50_linear.txt
# input file:  stack1_ub_summary_1500_cubic.txt
# input file:  stack1_ub_summary_250_linear.txt
# input file:  stack19_ub_summary_2000_cubic.txt
# input file:  stack10_ub_summary_2000_cubic.txt
# input file:  stack1_ub_summary_1500_linear.txt
# input file:  stack10_ub_summary_50_linear.txt
# input file:  stack15_ub_summary_250_linear.txt
# input file:  stack15_ub_summary_2000_linear.txt
# input file:  stack15_ub_summary_750_cubic.txt
# input file:  stack15_ub_summary_250_cubic.txt
# input file:  stack18_ub_summary_750_cubic.txt
# input file:  stack1_ub_summary_750_cubic.txt
# input file:  stack10_ub_summary_750_linear.txt
# input file:  stack18_ub_summary_250_linear.txt
# input file:  stack10_ub_summary_50_cubic.txt
# input file:  stack19_ub_summary_50_linear.txt
# input file:  stack10_ub_summary_250_cubic.txt
# input file:  stack18_ub_summary_250_cubic.txt
# input file:  stack19_ub_summary_250_cubic.txt
# input file:  stack18_ub_summary_2000_cubic.txt

# %%
all_metrics
# Out:
# defaultdict(list,
#             {'stack1': [[50.0, 'cubic', 19478.07, 0.00157, 6.8],
#               [2000.0, 'cubic', 19600.02, 0.00085, 6.7],
#               [50.0, 'linear', 19474.57, -0.01546, 6.8],
#               [250.0, 'cubic', 19485.45, 0.00143, 6.8],
#               [750.0, 'linear', 19492.24, -0.01549, 6.8],
#               [2000.0, 'linear', 19501.07, -0.01552, 6.8],
#               [1500.0, 'cubic', 19600.02, 0.00087, 6.7],
#               [250.0, 'linear', 19479.67, -0.01539, 6.8],
#               [1500.0, 'linear', 19499.6, -0.01554, 6.8],
#               [750.0, 'cubic', 19498.14, 0.00121, 6.8]],
#              'stack10': [[250.0, 'linear', 24774.79, 0.00353, 5.7],
#               [1500.0, 'cubic', 24766.57, 0.01289, 6.0],
#               [1500.0, 'linear', 24768.59, 0.00302, 6.0],
#               [750.0, 'cubic', 24766.78, 0.01277, 6.0],
#               [2000.0, 'linear', 24765.12, 0.00291, 5.8],
#               [2000.0, 'cubic', 24766.14, 0.0129, 6.0],
#               [50.0, 'linear', 24774.23, 0.00347, 5.7],
#               [750.0, 'linear', 24772.68, 0.00327, 5.7],
#               [50.0, 'cubic', 24763.8, 0.01268, 5.7],
#               [250.0, 'cubic', 24763.94, 0.01268, 5.7]],
#              'stack18': [[50.0, 'cubic', 18109.25, 0.01605, 5.5],
#               [1500.0, 'cubic', 18126.3, 0.01575, 5.4],
#               [750.0, 'linear', 18091.06, 0.00052, 5.8],
#               [2000.0, 'linear', 18095.23, 0.00079, 5.8],
#               [1500.0, 'linear', 18094.82, 0.0007, 5.8],
#               [50.0, 'linear', 18200.02, -0.00047, 5.8],
#               [750.0, 'cubic', 18121.73, 0.01583, 5.5],
#               [250.0, 'linear', 18084.8, 0.00028, 5.8],
#               [250.0, 'cubic', 18114.86, 0.01593, 5.5],
#               [2000.0, 'cubic', 18127.52, 0.01576, 5.4]],
#              'stack15': [[2000.0, 'cubic', 6029.42, 0.00919, 1536.0],
#               [750.0, 'linear', 6095.64, -0.00119, 1536.0],
#               [50.0, 'cubic', 5862.58, 0.01177, 1536.0],
#               [1500.0, 'cubic', 6030.98, 0.00935, 1536.0],
#               [1500.0, 'linear', 16631.39, 0.00147, 1536.0],
#               [50.0, 'linear', 5898.1, 0.00355, 1536.0],
#               [250.0, 'linear', 6200.0, 0.0015, 1536.0],
#               [2000.0, 'linear', 16588.48, 0.00152, 1536.0],
#               [750.0, 'cubic', 6175.86, 0.00981, 1536.0],
#               [250.0, 'cubic', 6199.87, 0.01196, 1536.0]],
#              'stack19': [[750.0, 'cubic', 19568.62, 0.00875, 5.3],
#               [2000.0, 'linear', 19544.48, -0.01309, 5.8],
#               [1500.0, 'cubic', 19569.92, 0.00873, 5.4],
#               [1500.0, 'linear', 19553.18, -0.01335, 5.8],
#               [750.0, 'linear', 19557.14, -0.01374, 5.8],
#               [50.0, 'cubic', 19568.81, 0.0083, 5.4],
#               [250.0, 'linear', 19557.09, -0.01407, 5.8],
#               [2000.0, 'cubic', 19568.8, 0.00874, 5.4],
#               [50.0, 'linear', 19559.62, -0.01425, 5.8],
#               [250.0, 'cubic', 19567.29, 0.00849, 5.4]]})

# %%
plt.rcParams.update({'font.size': 22})
for i,stack in enumerate(all_metrics.keys()):
    num = i+1
    stack_num = int(stack.split('stack')[-1])
    stack_metrics=np.array(all_metrics[stack])
    hard_threshold_mul = sorted(set(stack_metrics.T[0]))
    print(hard_threshold_mul)

    bfactors = sorted(set(stack_metrics.T[1]))
    print(bfactors)

    twoddefocus=[]
    twodscores=[]
    twodfit=[]
    scores=[]
    fit=[]
    for thres in hard_threshold_mul:
        vals=np.array(list(filter(lambda x: x[0] == float(thres), stack_metrics)),dtype='float32')
        order = vals[:,1].argsort()
    #     print(order)
    #     print(vals[order])
        twoddefocus.append(list(vals[order][:,2]))
        twodscores.append(list(vals[order][:,3]))
        twodfit.append(list(vals[order][:,4]))
        means=vals.mean(axis=0)
        scores.append(means[3])
        fit.append(means[4])
    #     print(vals[:,3])
    # print(twodscores)
    # print(twodfit)
#     print(twodscores)
    extent = [min(bfactors), max(bfactors), max(hard_threshold_mul), min(hard_threshold_mul)]

    fig, axes = plt.subplots(1, 3,figsize=(30,10))
#     fig.subplots_adjust(left=0.02, bottom=0.06, right=0.95, top=0.94, wspace=0.05)

    # fig, ax = plt.subplots()
    # divider = make_axes_locatable(ax)
    # cax = divider.append_axes('right', size='5%', pad=0.05)

    mat = axes[0].matshow(twoddefocus,extent=extent,aspect='auto')
    axes[0].set_title('defocus {}'.format(stack_num))
    fig.colorbar(mat,ax=axes[0])

    mat = axes[1].matshow(twodscores,extent=extent,aspect='auto')
    axes[1].set_title('score {}'.format(stack_num))
    fig.colorbar(mat,ax=axes[1])

    mat = axes[2].matshow(twodfit,extent=extent,aspect='auto')
    axes[2].set_title('fit {}'.format(stack_num))
    fig.colorbar(mat,ax=axes[2])
# Out:
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
# [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0]
# [0.0, 250.0, 500.0, 750.0, 1000.0, 1250.0, 1500.0, 1750.0, 2000.0]
